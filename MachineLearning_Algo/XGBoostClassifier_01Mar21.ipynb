# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import time

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Get the vibration signal features data

# %%
features_data = pd.read_csv('C:/Users/intel/Desktop/Mtech_Proj/Digital twin_29 Jan 2021/Low_features_digitalTwin_fault.csv',
                            index_col=0)

# %%
features_data.head()
# Out:
#      x_Mean     x_Min  x_Kurtosis  x_Crest_Factor  x_Skewness  x_Form_Factor  \
# 0 -0.015542 -0.531908    1.559893        4.469807   -0.080251      -8.142677
# 1 -0.014872 -0.609838    1.760466        4.377686   -0.269365      -8.633299
# 2 -0.017018 -0.646336    1.809119        4.169048   -0.063207      -7.533026
# 3 -0.011631 -0.547362    1.774470        4.277821   -0.079043     -11.263617
# 4 -0.018077 -0.573010    1.413154        4.211090   -0.098778      -7.016276
#
#   fault_Class
# 0          C1
# 1          C1
# 2          C1
# 3          C1
# 4          C1

# %% [markdown]
# # Train Test Split
#
# ** Split your data into a training set and a testing set.**

# %%
from sklearn.model_selection import train_test_split

# %%
X = features_data.drop('fault_Class',axis=1)
y = features_data['fault_Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
model = XGBClassifier()

# %%
start = time.time()
model.fit(X_train,y_train,verbose=1)
stop = time.time()
print(f"Training time: {stop - start}s")
# Out:
# Training time: 1.291224718093872s

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[412   0  74   0   0]
#  [  0 538   0   0   0]
#  [109   0 423   0   0]
#  [  0   0   0 525   0]
#  [  0   0   0   0 559]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           C1       0.79      0.85      0.82       486
#           C2       1.00      1.00      1.00       538
#           C3       0.85      0.80      0.82       532
#           C4       1.00      1.00      1.00       525
#           C5       1.00      1.00      1.00       559
#
#     accuracy                           0.93      2640
#    macro avg       0.93      0.93      0.93      2640
# weighted avg       0.93      0.93      0.93      2640

# %% [markdown]
# We noticed that your model was pretty good! Let's see if we can tune the parameters to try to get even better.Let try to use GridSearch.

# %% [markdown]
# ## Gridsearch Approach
#
# ** Import GridsearchCV from SciKit Learn.**

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# **Create a dictionary called param_grid and fill out some parameters for C and gamma.**

# %%
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001]}

# %% [markdown]
# ** Create a GridSearchCV object and fit it to the training data.**

# %%
grid = GridSearchCV(XGBClassifier(),param_grid,refit=True,verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=0.1, gamma=1 ..................................................
# [17:14:48] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................... C=0.1, gamma=1, total=   0.9s
# [CV] C=0.1, gamma=1 ..................................................
# [17:14:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV] ................................... C=0.1, gamma=1, total=   0.9s
# [CV] C=0.1, gamma=1 ..................................................
# [17:14:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=0.1, gamma=1, total=   0.9s
# [CV] C=0.1, gamma=1 ..................................................
# [17:14:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=0.1, gamma=1, total=   1.7s
# [CV] C=0.1, gamma=1 ..................................................
# [17:14:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=0.1, gamma=1, total=   0.9s
# [CV] C=0.1, gamma=0.1 ................................................
# [17:14:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=0.1, gamma=0.1, total=   0.9s
# [CV] C=0.1, gamma=0.1 ................................................
# [17:14:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=0.1, gamma=0.1, total=   1.2s
# [CV] C=0.1, gamma=0.1 ................................................
# [17:14:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=0.1, gamma=0.1, total=   0.8s
# [CV] C=0.1, gamma=0.1 ................................................
# [17:14:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=0.1, gamma=0.1, total=   0.8s
# [CV] C=0.1, gamma=0.1 ................................................
# [17:14:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=0.1, gamma=0.1, total=   1.2s
# [CV] C=0.1, gamma=0.01 ...............................................
# [17:14:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=0.1, gamma=0.01, total=   0.9s
# [CV] C=0.1, gamma=0.01 ...............................................
# [17:14:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=0.1, gamma=0.01, total=   0.8s
# [CV] C=0.1, gamma=0.01 ...............................................
# [17:15:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=0.1, gamma=0.01, total=   1.2s
# [CV] C=0.1, gamma=0.01 ...............................................
# [17:15:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=0.1, gamma=0.01, total=   0.9s
# [CV] C=0.1, gamma=0.01 ...............................................
# [17:15:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=0.1, gamma=0.01, total=   0.8s
# [CV] C=0.1, gamma=0.001 ..............................................
# [17:15:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=0.1, gamma=0.001, total=   1.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [17:15:04] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=0.1, gamma=0.001, total=   1.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [17:15:05] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV] ............................... C=0.1, gamma=0.001, total=   0.8s
# [CV] C=0.1, gamma=0.001 ..............................................
# [17:15:06] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=0.1, gamma=0.001, total=   1.3s
# [CV] C=0.1, gamma=0.001 ..............................................
# [17:15:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=0.1, gamma=0.001, total=   1.2s
# [CV] C=1, gamma=1 ....................................................
# [17:15:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ..................................... C=1, gamma=1, total=   0.9s
# [CV] C=1, gamma=1 ....................................................
# [17:15:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ..................................... C=1, gamma=1, total=   1.2s
# [CV] C=1, gamma=1 ....................................................
# [17:15:10] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ..................................... C=1, gamma=1, total=   1.0s
# [CV] C=1, gamma=1 ....................................................
# [17:15:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ..................................... C=1, gamma=1, total=   0.9s
# [CV] C=1, gamma=1 ....................................................
# [17:15:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ..................................... C=1, gamma=1, total=   1.3s
# [CV] C=1, gamma=0.1 ..................................................
# [17:15:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=1, gamma=0.1, total=   0.9s
# [CV] C=1, gamma=0.1 ..................................................
# [17:15:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=1, gamma=0.1, total=   0.9s
# [CV] C=1, gamma=0.1 ..................................................
# [17:15:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=1, gamma=0.1, total=   1.2s
# [CV] C=1, gamma=0.1 ..................................................
# [17:15:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=1, gamma=0.1, total=   1.0s
# [CV] C=1, gamma=0.1 ..................................................
# [17:15:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=1, gamma=0.1, total=   0.8s
# [CV] C=1, gamma=0.01 .................................................
# [17:15:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=1, gamma=0.01, total=   1.2s
# [CV] C=1, gamma=0.01 .................................................
# [17:15:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=1, gamma=0.01, total=   1.1s
# [CV] C=1, gamma=0.01 .................................................
# [17:15:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=1, gamma=0.01, total=   0.9s
# [CV] C=1, gamma=0.01 .................................................
# [17:15:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV] .................................. C=1, gamma=0.01, total=   1.3s
# [CV] C=1, gamma=0.01 .................................................
# [17:15:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=1, gamma=0.01, total=   1.2s
# [CV] C=1, gamma=0.001 ................................................
# [17:15:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=1, gamma=0.001, total=   0.8s
# [CV] C=1, gamma=0.001 ................................................
# [17:15:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=1, gamma=0.001, total=   1.2s
# [CV] C=1, gamma=0.001 ................................................
# [17:15:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=1, gamma=0.001, total=   0.9s
# [CV] C=1, gamma=0.001 ................................................
# [17:15:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=1, gamma=0.001, total=   0.8s
# [CV] C=1, gamma=0.001 ................................................
# [17:15:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=1, gamma=0.001, total=   1.1s
# [CV] C=10, gamma=1 ...................................................
# [17:15:29] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................... C=10, gamma=1, total=   1.1s
# [CV] C=10, gamma=1 ...................................................
# [17:15:30] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................... C=10, gamma=1, total=   0.8s
# [CV] C=10, gamma=1 ...................................................
# [17:15:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................... C=10, gamma=1, total=   1.1s
# [CV] C=10, gamma=1 ...................................................
# [17:15:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................... C=10, gamma=1, total=   1.3s
# [CV] C=10, gamma=1 ...................................................
# [17:15:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................... C=10, gamma=1, total=   1.3s
# [CV] C=10, gamma=0.1 .................................................
# [17:15:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=10, gamma=0.1, total=   0.8s
# [CV] C=10, gamma=0.1 .................................................
# [17:15:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=10, gamma=0.1, total=   0.9s
# [CV] C=10, gamma=0.1 .................................................
# [17:15:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=10, gamma=0.1, total=   1.2s
# [CV] C=10, gamma=0.1 .................................................
# [17:15:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] .................................. C=10, gamma=0.1, total=   1.4s
# [CV] C=10, gamma=0.1 .................................................
# [17:15:39] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV] .................................. C=10, gamma=0.1, total=   1.2s
# [CV] C=10, gamma=0.01 ................................................
# [17:15:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=10, gamma=0.01, total=   1.1s
# [CV] C=10, gamma=0.01 ................................................
# [17:15:41] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=10, gamma=0.01, total=   1.4s
# [CV] C=10, gamma=0.01 ................................................
# [17:15:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=10, gamma=0.01, total=   1.3s
# [CV] C=10, gamma=0.01 ................................................
# [17:15:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=10, gamma=0.01, total=   1.3s
# [CV] C=10, gamma=0.01 ................................................
# [17:15:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=10, gamma=0.01, total=   0.9s
# [CV] C=10, gamma=0.001 ...............................................
# [17:15:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=10, gamma=0.001, total=   0.9s
# [CV] C=10, gamma=0.001 ...............................................
# [17:15:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=10, gamma=0.001, total=   0.8s
# [CV] C=10, gamma=0.001 ...............................................
# [17:15:48] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=10, gamma=0.001, total=   1.0s
# [CV] C=10, gamma=0.001 ...............................................
# [17:15:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=10, gamma=0.001, total=   1.2s
# [CV] C=10, gamma=0.001 ...............................................
# [17:15:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=10, gamma=0.001, total=   1.2s
# [CV] C=100, gamma=1 ..................................................
# [17:15:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=100, gamma=1, total=   1.3s
# [CV] C=100, gamma=1 ..................................................
# [17:15:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=100, gamma=1, total=   1.3s
# [CV] C=100, gamma=1 ..................................................
# [17:15:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=100, gamma=1, total=   1.3s
# [CV] C=100, gamma=1 ..................................................
# [17:15:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=100, gamma=1, total=   1.0s
# [CV] C=100, gamma=1 ..................................................
# [17:15:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................... C=100, gamma=1, total=   1.3s
# [CV] C=100, gamma=0.1 ................................................
# [17:15:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV] ................................. C=100, gamma=0.1, total=   1.2s
# [CV] C=100, gamma=0.1 ................................................
# [17:15:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=100, gamma=0.1, total=   1.2s
# [CV] C=100, gamma=0.1 ................................................
# [17:16:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=100, gamma=0.1, total=   1.1s
# [CV] C=100, gamma=0.1 ................................................
# [17:16:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=100, gamma=0.1, total=   0.8s
# [CV] C=100, gamma=0.1 ................................................
# [17:16:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................. C=100, gamma=0.1, total=   0.9s
# [CV] C=100, gamma=0.01 ...............................................
# [17:16:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=100, gamma=0.01, total=   1.2s
# [CV] C=100, gamma=0.01 ...............................................
# [17:16:04] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=100, gamma=0.01, total=   1.2s
# [CV] C=100, gamma=0.01 ...............................................
# [17:16:05] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=100, gamma=0.01, total=   0.9s
# [CV] C=100, gamma=0.01 ...............................................
# [17:16:06] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=100, gamma=0.01, total=   0.8s
# [CV] C=100, gamma=0.01 ...............................................
# [17:16:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ................................ C=100, gamma=0.01, total=   1.2s
# [CV] C=100, gamma=0.001 ..............................................
# [17:16:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=100, gamma=0.001, total=   1.3s
# [CV] C=100, gamma=0.001 ..............................................
# [17:16:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=100, gamma=0.001, total=   1.4s
# [CV] C=100, gamma=0.001 ..............................................
# [17:16:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=100, gamma=0.001, total=   1.8s
# [CV] C=100, gamma=0.001 ..............................................
# [17:16:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=100, gamma=0.001, total=   1.3s
# [CV] C=100, gamma=0.001 ..............................................
# [17:16:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV] ............................... C=100, gamma=0.001, total=   1.2s
# [17:16:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { C } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  1.5min finished
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, subsample=None,
#                                      tree_method=None, validate_parameters=None,
#                                      verbosity=None),
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': [1, 0.1, 0.01, 0.001]},
#              verbose=2)

# %% [markdown]
# ** Now take that grid model and create some predictions using the test set and create classification reports and confusion matrices for them. lets find if we were able to improve?**

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[405   0  81   0   0]
#  [  0 538   0   0   0]
#  [106   0 426   0   0]
#  [  0   0   0 525   0]
#  [  0   0   0   0 559]]

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#           C1       0.79      0.83      0.81       486
#           C2       1.00      1.00      1.00       538
#           C3       0.84      0.80      0.82       532
#           C4       1.00      1.00      1.00       525
#           C5       1.00      1.00      1.00       559
#
#     accuracy                           0.93      2640
#    macro avg       0.93      0.93      0.93      2640
# weighted avg       0.93      0.93      0.93      2640

# %%
# pwd
# Out:
# 'C:\\Users\\intel\\Desktop\\Mtech_Proj\\Shallow_Methods_28Jul'
